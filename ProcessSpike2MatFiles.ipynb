# %% [markdown]
# # Convert data to dat for analysis

# %%
# Run an example
from spike2_utils import load_and_pack_WB
import numpy as np
import os

mat_file_loc = r'C:\Users\bsriram\Desktop\Data\PGRN\MatFiles'
sessions_loc = r'C:\Users\bsriram\Desktop\Data\PGRN\Sessions'


# WT_2
subject = 'PGRN_WT_2'
base_loc = os.path.join(mat_file_loc,subject)
save_loc = os.path.join(sessions_loc,subject)
sessions = [(subject,'S1','Loc1','whiskerstim','A'),
           (subject,'S1','Loc1','whiskerstim','C'),
           (subject,'V1','Loc3','VisStim','B'),
           (subject,'V1','Loc3','VisStim','D'),
           (subject,'V1','Loc3','VisStim_LFP','B'),
           (subject,'dLGN','Loc4','VisStim','B'),
           (subject,'dLGN','Loc4','VisStim','D')]
channel_sequence = np.array([9,7,10,8,13,3,12,5,15,2,16,1,14,4,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)

# %%
from spike2_utils import load_and_pack_WB
import numpy as np
import os

mat_file_loc = r'C:\Users\bsriram\Desktop\Data\PGRN\MatFiles'


# WT_2
subject = 'PGRN_WT_2'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'S1','Loc1','whiskerstim','A'),
           (subject,'S1','Loc1','whiskerstim','C'),
           (subject,'V1','Loc3','VisStim','B'),
           (subject,'V1','Loc3','VisStim','D'),
           (subject,'V1','Loc3','VisStim_LFP','B'),
           (subject,'dLGN','Loc4','VisStim','B'),
           (subject,'dLGN','Loc4','VisStim','D')]
channel_sequence = np.array([9,7,10,8,13,3,12,5,15,2,16,1,14,4,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)
    
# WT_3
subject = 'PGRN_WT_3'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'S1','Loc1','whiskerstim','A'),
           (subject,'S1','Loc1','whiskerstim','C'),
           (subject,'V1','Loc2','VisStim','B'),
           (subject,'V1','Loc2','VisStim','D'),
           (subject,'dLGN','Loc3','VisStim','B'),
           (subject,'dLGN','Loc3','VisStim','D')]
channel_sequence = np.array([9,7,10,8,13,3,12,5,15,2,16,1,14,4,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)

# WT_4
subject = 'PGRN_WT_4'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'S1','Loc1','whiskerstim','A'),
           (subject,'S1','Loc1','whiskerstim','A2'),
           (subject,'S1','Loc1','whiskerstim','C'),
           (subject,'V1','Loc2','VisStim','B'),
           (subject,'V1','Loc2','VisStim','D'),
           (subject,'dLGN','Loc3','VisStim','B'),
           (subject,'dLGN','Loc3','VisStim','D')]
channel_sequence = np.array([9,7,10,8,13,3,12,5,15,2,16,1,14,4,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)

# WT_5
subject = 'PGRN_WT_5'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'S1','Loc1','whiskerstim','A'),
           (subject,'S1','Loc1','whiskerstim','C'),
           (subject,'V1','Loc2','VisStim','B'),
           (subject,'V1','Loc2','VisStim','D'),
           (subject,'dLGN','Loc3','VisStim','B'),
           (subject,'dLGN','Loc3','VisStim','D')]
channel_sequence = np.array([9,7,10,8,13,3,12,5,15,2,16,1,14,4,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)

# WT_6
subject = 'PGRN_WT_6'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'S1','Loc1','whiskerstim','A'),
           (subject,'S1','Loc1','whiskerstim','C'),
           (subject,'V2','Loc2','VisStim','B'),
           (subject,'V2','Loc2','VisStim','D'),
           (subject,'V1','Loc3','VisStim','B'),
           (subject,'V1','Loc3','VisStim','D'),
           (subject,'dLGN','Loc4','VisStim','B'),
           (subject,'dLGN','Loc4','VisStim','D')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)

# WT_7
subject = 'PGRN_WT_7'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'S1','Loc1','whiskerstim','A'),
           (subject,'S1','Loc1','whiskerstim','C'),
           (subject,'V1','Loc2','VisStim','B'),
           (subject,'V1','Loc2','VisStim','D'),
           (subject,'dLGN','Loc3','VisStim','B'),
           (subject,'dLGN','Loc3','VisStim','D')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)

# WT_8
subject = 'PGRN_WT_8'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'S1','Loc1','whiskerstim','A'),
           (subject,'S1','Loc1','whiskerstim','C'),
           (subject,'V1','Loc2','VisStim','B'),
           (subject,'V1','Loc2','VisStim','D'),
           (subject,'V1','Loc3','VisStim','B'),
           (subject,'V1','Loc3','VisStim','D'),
           (subject,'dLGN','Loc4','VisStim','B'),
           (subject,'dLGN','Loc4','VisStim','D')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)

# WT_9
subject = 'PGRN_WT_9'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'S1','Loc1','whiskerstim','A'),
           (subject,'S1','Loc1','whiskerstim','C'),
           (subject,'VPLM','Loc2','whiskerstim','A'),
           (subject,'VPLM','Loc2','whiskerstim','C'),
           (subject,'VPLM','Loc3','whiskerstim','C'),
           (subject,'V1','Loc4','VisStim','B'),
           (subject,'V1','Loc4','VisStim','D')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)

# WT_10
subject = 'PGRN_WT_10'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'S1','Loc1','whiskerstim','A'),
           (subject,'S1','Loc1','whiskerstim','C'),
           (subject,'VPLM','Loc2','whiskerstim','A'),
           (subject,'VPLM','Loc2','whiskerstim','C'),
           (subject,'V1','Loc3','VisStim','B'),
           (subject,'V1','Loc3','VisStim','D'),
           (subject,'dLGN','Loc4','VisStim','B'),
           (subject,'dLGN','Loc4','VisStim','D'),
           (subject,'dLGN','Loc4','VisStim','D2')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)

# WT_11
subject = 'PGRN_WT_11'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'S1','Loc1','whiskerstim','A'),
           (subject,'S1','Loc1','whiskerstim','C'),
           (subject,'VPLM','Loc2','whiskerstim','A'),
           (subject,'VPLM','Loc2','whiskerstim','C'),
           (subject,'V1','Loc3','VisStim','B'),
           (subject,'V1','Loc3','VisStim','D'),
           (subject,'dLGN','Loc4','VisStim','B'),
           (subject,'dLGN','Loc4','VisStim','D'),
           (subject,'dLGN','Loc5','VisStim','B'),
           (subject,'dLGN','Loc5','VisStim','D'),
           (subject,'V1','Loc6','VisStim','B'),
           (subject,'V1','Loc6','VisStim','D'),
           ]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)

##Data with Picrotoxin

# WT_12
subject = 'PGRN_WT_12'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','D'),
            (subject,'V1','Loc2','VisStim','D'),
            (subject,'V1','Loc2','VisStim','D2'),
            (subject,'V1','Loc2','VisStim','D3'),
            (subject,'V1','Loc2','VisStim','D4'),
            (subject,'V1','Loc2','VisStim','D5'),
            (subject,'V1','Loc2','VisStim','D6'),
            (subject,'V1','Loc2','SPONT','1'),
            (subject,'V1','Loc2','SPONT','2'),
            (subject,'V1','Loc2','SPONT','3'),
            (subject,'V1','Loc2','SPONT','4')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)

# WT_13
subject = 'PGRN_WT_13'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','D'),
            (subject,'V1','Loc2','VisStim','D'),
            (subject,'V1','Loc2','VisStim','D1'),
            (subject,'V1','Loc2','VisStim','D2'),
            (subject,'V1','Loc2','VisStim','D3'),
            (subject,'V1','Loc2','VisStim','D4'),
            (subject,'V1','Loc2','SPONT','1'),
            (subject,'V1','Loc2','SPONT','2'),
            (subject,'V1','Loc2','SPONT','3')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)

# WT_14
subject = 'PGRN_WT_14'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','D'),
            (subject,'V1','Loc1','VisStim','D2'),
            #(subject,'V1','Loc1','VisStim','D3'),
            (subject,'V1','Loc1','VisStim','D4'),
            (subject,'V1','Loc1','SPONT','1'),
            (subject,'V1','Loc1','SPONT','2')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)

## Final cohort for WT
# WT_15
subject = 'PGRN_WT_15'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','B'),
            (subject,'V1','Loc1','VisStim','D'),
            (subject,'V1','Loc2','VisStim','B'),
            (subject,'dLGN','Loc3','VisStim','B'),
            (subject,'dLGN','Loc3','VisStim','D'),
            (subject,'S1','Loc4','WhiskStim','A'),
            (subject,'S1','Loc4','WhiskStim','C'),
            (subject,'VPLM','Loc5','WhiskStim','A'),
            (subject,'VPLM','Loc5','WhiskStim','C'),]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)

# WT_16
subject = 'PGRN_WT_16'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','B'),
            (subject,'V1','Loc1','VisStim','D'),
            (subject,'dLGN','Loc2','VisStim','B'),
            (subject,'dLGN','Loc2','VisStim','D'),
            (subject,'S1','Loc3','WhiskStim','A'),
            (subject,'S1','Loc3','WhiskStim','C'),
            (subject,'S1','Loc4','WhiskStim','A'),
            (subject,'VPLM','Loc5','WhiskStim','A'),
            (subject,'VPLM','Loc5','WhiskStim','C'),]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)


# WT_17
subject = 'PGRN_WT_17'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','B'),
            (subject,'V1','Loc1','VisStim','D'),
            (subject,'V1','Loc2','VisStim','B'),
            (subject,'V1','Loc2','VisStim','D'),
            (subject,'dLGN','Loc3','VisStim','B'),
            (subject,'dLGN','Loc3','VisStim','D'),
            (subject,'S1','Loc4','WhiskStim','A'),
            (subject,'S1','Loc4','WhiskStim','C'),
            (subject,'VPLM','Loc5','WhiskStim','A'),
            (subject,'VPLM','Loc5','WhiskStim','C'),]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)

# WT_18
subject = 'PGRN_WT_18'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','B'),
            (subject,'V1','Loc1','VisStim','D'),
            (subject,'dLGN','Loc2','VisStim','B'),
            (subject,'dLGN','Loc2','VisStim','D'),
            (subject,'dLGN','Loc3','VisStim','B'),
            (subject,'dLGN','Loc3','VisStim','D'),
            (subject,'S1','Loc4','WhiskStim','A'),
            (subject,'S1','Loc4','WhiskStim','C'),
            (subject,'VPLM','Loc5','WhiskStim','A'),
            (subject,'VPLM','Loc5','WhiskStim','C'),]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)

# WT_19
subject = 'PGRN_WT_19'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','B'),
            (subject,'V1','Loc1','VisStim','D'),
            (subject,'dLGN','Loc2','VisStim','B'),
            (subject,'dLGN','Loc2','VisStim','D'),
            (subject,'S1','Loc3','WhiskStim','A'),
            (subject,'S1','Loc3','WhiskStim','C'),
            (subject,'VPLM','Loc4','WhiskStim','A'),
            (subject,'VPLM','Loc4','WhiskStim','C'),]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)

## HOMOZYGOUS ANIMALS
# HOM_1
subject = 'PGRN_HOM_1'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','B'),
            (subject,'V1','Loc1','VisStim','D'),
            (subject,'dLGN','Loc2','VisStim','B'),
            (subject,'dLGN','Loc2','VisStim','D'),
            (subject,'S1','Loc3','WhiskStim','A'),
            (subject,'S1','Loc3','WhiskStim','C'),
            (subject,'VPLM','Loc4','WhiskStim','A'),
            (subject,'VPLM','Loc4','WhiskStim','C')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)

    
# HOM_2
subject = 'PGRN_HOM_2'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','B'),
            (subject,'V1','Loc1','VisStim','D'),
            (subject,'dLGN','Loc2','VisStim','B'),
            (subject,'dLGN','Loc2','VisStim','D'),
            (subject,'S1','Loc3','WhiskStim','A'),
            (subject,'S1','Loc3','WhiskStim','C'),
            (subject,'VPLM','Loc4','WhiskStim','A'),
            (subject,'VPLM','Loc4','WhiskStim','C')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)

    
# HOM_3
subject = 'PGRN_HOM_3'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','B'),
            (subject,'V1','Loc1','VisStim','D'),
            (subject,'dLGN','Loc2','VisStim','B'),
            (subject,'dLGN','Loc2','VisStim','D'),
            (subject,'S1','Loc3','WhiskStim','A'),
            (subject,'S1','Loc3','WhiskStim','C'),
            (subject,'VPLM','Loc4','WhiskStim','A'),
            (subject,'VPLM','Loc4','WhiskStim','C'),
            (subject,'VPLM','Loc5','WhiskStim','A'),
            (subject,'VPLM','Loc6','WhiskStim','A'),
            (subject,'VPLM','Loc6','WhiskStim','C')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)

    
# HOM_4
subject = 'PGRN_HOM_4'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','B'),
            (subject,'V1','Loc1','VisStim','D'),
            (subject,'dLGN','Loc2','VisStim','B'),
            (subject,'dLGN','Loc2','VisStim','D'),
            (subject,'S1','Loc5','WhiskStim','A'),
            (subject,'S1','Loc5','WhiskStim','C'),
            (subject,'S1','Loc5','WhiskStim','A1'),
            (subject,'S1','Loc5','WhiskStim','C1'),
            (subject,'VPLM','Loc3','WhiskStim','A'),
            (subject,'VPLM','Loc3','WhiskStim','C'),
            (subject,'VPLM','Loc4','WhiskStim','A'),
            (subject,'VPLM','Loc4','WhiskStim','C'),
            (subject,'VPLM','Loc6','WhiskStim','A'),
            (subject,'VPLM','Loc6','WhiskStim','C')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)

    
# HOM_5
subject = 'PGRN_HOM_5'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','B'),
            (subject,'V1','Loc1','VisStim','D'),
            (subject,'dLGN','Loc2','VisStim','B'),
            (subject,'dLGN','Loc2','VisStim','D'),
            (subject,'dLGN','Loc3','VisStim','B'),
            (subject,'dLGN','Loc3','VisStim','D'),
#             (subject,'S1','Loc4','WhiskStim','A'),
            (subject,'S1','Loc5','WhiskStim','A'),
            (subject,'S1','Loc5','WhiskStim','C'),
            (subject,'VPLM','Loc6','WhiskStim','A'),
            (subject,'VPLM','Loc6','WhiskStim','C')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_WB(base_loc,session,output_loc=None,recorded_sequence=channel_sequence)

# %% [markdown]
# # Process timestamps

# %%
from spike2_utils import load_and_pack_timestamps
import numpy as np
import os

mat_file_loc = r'C:\Users\bsriram\Desktop\Data\PGRN\MatFiles'

# # WT_2
# subject = 'PGRN_WT_2'
# base_loc = os.path.join(mat_file_loc,subject)
# sessions = [(subject,'S1','Loc1','whiskerstim','A'),
#            (subject,'S1','Loc1','whiskerstim','C'),
#            (subject,'V1','Loc3','VisStim','B'),
#            (subject,'V1','Loc3','VisStim','D'),
#            (subject,'V1','Loc3','VisStim_LFP','B'),
#            (subject,'dLGN','Loc4','VisStim','B'),
#            (subject,'dLGN','Loc4','VisStim','D')]
# channel_sequence = np.array([9,7,10,8,13,3,12,5,15,2,16,1,14,4,11,6])
# for session in sessions:
#     load_and_pack_timestamps(base_loc,session)
    
# WT_3
subject = 'PGRN_WT_3'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'S1','Loc1','whiskerstim','A'),
           (subject,'S1','Loc1','whiskerstim','C'),
           (subject,'V1','Loc2','VisStim','B'),
           (subject,'V1','Loc2','VisStim','D'),
           (subject,'dLGN','Loc3','VisStim','B'),
           (subject,'dLGN','Loc3','VisStim','D')]
channel_sequence = np.array([9,7,10,8,13,3,12,5,15,2,16,1,14,4,11,6])
for session in sessions:
    load_and_pack_timestamps(base_loc,session)

# WT_4
subject = 'PGRN_WT_4'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'S1','Loc1','whiskerstim','A'),
           (subject,'S1','Loc1','whiskerstim','A2'),
           (subject,'S1','Loc1','whiskerstim','C'),
           (subject,'V1','Loc2','VisStim','B'),
           (subject,'V1','Loc2','VisStim','D'),
           (subject,'dLGN','Loc3','VisStim','B'),
           (subject,'dLGN','Loc3','VisStim','D')]
channel_sequence = np.array([9,7,10,8,13,3,12,5,15,2,16,1,14,4,11,6])
for session in sessions:
    load_and_pack_timestamps(base_loc,session)

# WT_5
subject = 'PGRN_WT_5'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'S1','Loc1','whiskerstim','A'),
           (subject,'S1','Loc1','whiskerstim','C'),
           (subject,'V1','Loc2','VisStim','B'),
           (subject,'V1','Loc2','VisStim','D'),
           (subject,'dLGN','Loc3','VisStim','B'),
           (subject,'dLGN','Loc3','VisStim','D')]
channel_sequence = np.array([9,7,10,8,13,3,12,5,15,2,16,1,14,4,11,6])
for session in sessions:
    load_and_pack_timestamps(base_loc,session)

# WT_6
subject = 'PGRN_WT_6'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'S1','Loc1','whiskerstim','A'),
           (subject,'S1','Loc1','whiskerstim','C'),
           (subject,'V2','Loc2','VisStim','B'),
           (subject,'V2','Loc2','VisStim','D'),
           (subject,'V1','Loc3','VisStim','B'),
           (subject,'V1','Loc3','VisStim','D'),
           (subject,'dLGN','Loc4','VisStim','B'),
           (subject,'dLGN','Loc4','VisStim','D')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_timestamps(base_loc,session)

# WT_7
subject = 'PGRN_WT_7'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'S1','Loc1','whiskerstim','A'),
           (subject,'S1','Loc1','whiskerstim','C'),
           (subject,'V1','Loc2','VisStim','B'),
           (subject,'V1','Loc2','VisStim','D'),
           (subject,'dLGN','Loc3','VisStim','B'),
           (subject,'dLGN','Loc3','VisStim','D')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_timestamps(base_loc,session)

# WT_8
subject = 'PGRN_WT_8'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'S1','Loc1','whiskerstim','A'),
           (subject,'S1','Loc1','whiskerstim','C'),
           (subject,'V1','Loc2','VisStim','B'),
           (subject,'V1','Loc2','VisStim','D'),
           (subject,'V1','Loc3','VisStim','B'),
           (subject,'V1','Loc3','VisStim','D'),
           (subject,'dLGN','Loc4','VisStim','B'),
           (subject,'dLGN','Loc4','VisStim','D')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_timestamps(base_loc,session)

# WT_9
subject = 'PGRN_WT_9'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'S1','Loc1','whiskerstim','A'),
           (subject,'S1','Loc1','whiskerstim','C'),
           (subject,'VPLM','Loc2','whiskerstim','A'),
           (subject,'VPLM','Loc2','whiskerstim','C'),
           (subject,'VPLM','Loc3','whiskerstim','C'),
           (subject,'V1','Loc4','VisStim','B'),
           (subject,'V1','Loc4','VisStim','D')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_timestamps(base_loc,session)

# WT_10
subject = 'PGRN_WT_10'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'S1','Loc1','whiskerstim','A'),
           (subject,'S1','Loc1','whiskerstim','C'),
           (subject,'VPLM','Loc2','whiskerstim','A'),
           (subject,'VPLM','Loc2','whiskerstim','C'),
           (subject,'V1','Loc3','VisStim','B'),
           (subject,'V1','Loc3','VisStim','D'),
           (subject,'dLGN','Loc4','VisStim','B'),
           (subject,'dLGN','Loc4','VisStim','D'),
           (subject,'dLGN','Loc4','VisStim','D2')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_timestamps(base_loc,session)

# WT_11
subject = 'PGRN_WT_11'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'S1','Loc1','whiskerstim','A'),
           (subject,'S1','Loc1','whiskerstim','C'),
           (subject,'VPLM','Loc2','whiskerstim','A'),
           (subject,'VPLM','Loc2','whiskerstim','C'),
           (subject,'V1','Loc3','VisStim','B'),
           (subject,'V1','Loc3','VisStim','D'),
           (subject,'dLGN','Loc4','VisStim','B'),
           (subject,'dLGN','Loc4','VisStim','D'),
           (subject,'dLGN','Loc5','VisStim','B'),
           (subject,'dLGN','Loc5','VisStim','D'),
           (subject,'V1','Loc6','VisStim','B'),
           (subject,'V1','Loc6','VisStim','D'),
           ]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_timestamps(base_loc,session)

##Data with Picrotoxin

# WT_12
subject = 'PGRN_WT_12'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','D'),
            (subject,'V1','Loc2','VisStim','D'),
            (subject,'V1','Loc2','VisStim','D2'),
            (subject,'V1','Loc2','VisStim','D3'),
            (subject,'V1','Loc2','VisStim','D4'),
            (subject,'V1','Loc2','VisStim','D5'),
            (subject,'V1','Loc2','VisStim','D6'),
            (subject,'V1','Loc2','SPONT','1'),
            (subject,'V1','Loc2','SPONT','2'),
            (subject,'V1','Loc2','SPONT','3'),
            (subject,'V1','Loc2','SPONT','4')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_timestamps(base_loc,session)

# WT_13
subject = 'PGRN_WT_13'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','D'),
            (subject,'V1','Loc2','VisStim','D'),
            (subject,'V1','Loc2','VisStim','D1'),
            (subject,'V1','Loc2','VisStim','D2'),
            (subject,'V1','Loc2','VisStim','D3'),
            (subject,'V1','Loc2','VisStim','D4'),
            (subject,'V1','Loc2','SPONT','1'),
            (subject,'V1','Loc2','SPONT','2'),
            (subject,'V1','Loc2','SPONT','3')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_timestamps(base_loc,session)

# WT_14
subject = 'PGRN_WT_14'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','D'),
            (subject,'V1','Loc1','VisStim','D2'),
            #(subject,'V1','Loc1','VisStim','D3'),
            (subject,'V1','Loc1','VisStim','D4'),
            (subject,'V1','Loc1','SPONT','1'),
            (subject,'V1','Loc1','SPONT','2')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_timestamps(base_loc,session)

## Final cohort for WT
# WT_15
subject = 'PGRN_WT_15'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','B'),
            (subject,'V1','Loc1','VisStim','D'),
            (subject,'V1','Loc2','VisStim','B'),
            (subject,'dLGN','Loc3','VisStim','B'),
            (subject,'dLGN','Loc3','VisStim','D'),
            (subject,'S1','Loc4','WhiskStim','A'),
            (subject,'S1','Loc4','WhiskStim','C'),
            (subject,'VPLM','Loc5','WhiskStim','A'),
            (subject,'VPLM','Loc5','WhiskStim','C'),]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_timestamps(base_loc,session)

# WT_16
subject = 'PGRN_WT_16'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','B'),
            (subject,'V1','Loc1','VisStim','D'),
            (subject,'dLGN','Loc2','VisStim','B'),
            (subject,'dLGN','Loc2','VisStim','D'),
            (subject,'S1','Loc3','WhiskStim','A'),
            (subject,'S1','Loc3','WhiskStim','C'),
            (subject,'S1','Loc4','WhiskStim','A'),
            (subject,'VPLM','Loc5','WhiskStim','A'),
            (subject,'VPLM','Loc5','WhiskStim','C'),]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_timestamps(base_loc,session)


# WT_17
subject = 'PGRN_WT_17'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','B'),
            (subject,'V1','Loc1','VisStim','D'),
            (subject,'V1','Loc2','VisStim','B'),
            (subject,'V1','Loc2','VisStim','D'),
            (subject,'dLGN','Loc3','VisStim','B'),
            (subject,'dLGN','Loc3','VisStim','D'),
            (subject,'S1','Loc4','WhiskStim','A'),
            (subject,'S1','Loc4','WhiskStim','C'),
            (subject,'VPLM','Loc5','WhiskStim','A'),
            (subject,'VPLM','Loc5','WhiskStim','C'),]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_timestamps(base_loc,session)

# WT_18
subject = 'PGRN_WT_18'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','B'),
            (subject,'V1','Loc1','VisStim','D'),
            (subject,'dLGN','Loc2','VisStim','B'),
            (subject,'dLGN','Loc2','VisStim','D'),
            (subject,'dLGN','Loc3','VisStim','B'),
            (subject,'dLGN','Loc3','VisStim','D'),
            (subject,'S1','Loc4','WhiskStim','A'),
            (subject,'S1','Loc4','WhiskStim','C'),
            (subject,'VPLM','Loc5','WhiskStim','A'),
            (subject,'VPLM','Loc5','WhiskStim','C'),]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_timestamps(base_loc,session)

# WT_19
subject = 'PGRN_WT_19'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','B'),
            (subject,'V1','Loc1','VisStim','D'),
            (subject,'dLGN','Loc2','VisStim','B'),
            (subject,'dLGN','Loc2','VisStim','D'),
            (subject,'S1','Loc3','WhiskStim','A'),
            (subject,'S1','Loc3','WhiskStim','C'),
            (subject,'VPLM','Loc4','WhiskStim','A'),
            (subject,'VPLM','Loc4','WhiskStim','C'),]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_timestamps(base_loc,session)

## HOMOZYGOUS ANIMALS
# HOM_1
subject = 'PGRN_HOM_1'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','B'),
            (subject,'V1','Loc1','VisStim','D'),
            (subject,'dLGN','Loc2','VisStim','B'),
            (subject,'dLGN','Loc2','VisStim','D'),
            (subject,'S1','Loc3','WhiskStim','A'),
            (subject,'S1','Loc3','WhiskStim','C'),
            (subject,'VPLM','Loc4','WhiskStim','A'),
            (subject,'VPLM','Loc4','WhiskStim','C')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_timestamps(base_loc,session)

    
# HOM_2
subject = 'PGRN_HOM_2'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','B'),
            (subject,'V1','Loc1','VisStim','D'),
            (subject,'dLGN','Loc2','VisStim','B'),
            (subject,'dLGN','Loc2','VisStim','D'),
            (subject,'S1','Loc3','WhiskStim','A'),
            (subject,'S1','Loc3','WhiskStim','C'),
            (subject,'VPLM','Loc4','WhiskStim','A'),
            (subject,'VPLM','Loc4','WhiskStim','C')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_timestamps(base_loc,session)

    
# HOM_3
subject = 'PGRN_HOM_3'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','B'),
            (subject,'V1','Loc1','VisStim','D'),
            (subject,'dLGN','Loc2','VisStim','B'),
            (subject,'dLGN','Loc2','VisStim','D'),
            (subject,'S1','Loc3','WhiskStim','A'),
            (subject,'S1','Loc3','WhiskStim','C'),
            (subject,'VPLM','Loc4','WhiskStim','A'),
            (subject,'VPLM','Loc4','WhiskStim','C'),
            (subject,'VPLM','Loc5','WhiskStim','A'),
            (subject,'VPLM','Loc6','WhiskStim','A'),
            (subject,'VPLM','Loc6','WhiskStim','C')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_timestamps(base_loc,session)

    
# HOM_4
subject = 'PGRN_HOM_4'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','B'),
            (subject,'V1','Loc1','VisStim','D'),
            (subject,'dLGN','Loc2','VisStim','B'),
            (subject,'dLGN','Loc2','VisStim','D'),
            (subject,'S1','Loc5','WhiskStim','A'),
            (subject,'S1','Loc5','WhiskStim','C'),
            (subject,'S1','Loc5','WhiskStim','A1'),
            (subject,'S1','Loc5','WhiskStim','C1'),
            (subject,'VPLM','Loc3','WhiskStim','A'),
            (subject,'VPLM','Loc3','WhiskStim','C'),
            (subject,'VPLM','Loc4','WhiskStim','A'),
            (subject,'VPLM','Loc4','WhiskStim','C'),
            (subject,'VPLM','Loc6','WhiskStim','A'),
            (subject,'VPLM','Loc6','WhiskStim','C')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_timestamps(base_loc,session)

    
# HOM_5
subject = 'PGRN_HOM_5'
base_loc = os.path.join(mat_file_loc,subject)
sessions = [(subject,'V1','Loc1','VisStim','B'),
            (subject,'V1','Loc1','VisStim','D'),
            (subject,'dLGN','Loc2','VisStim','B'),
            (subject,'dLGN','Loc2','VisStim','D'),
            (subject,'dLGN','Loc3','VisStim','B'),
            (subject,'dLGN','Loc3','VisStim','D'),
#             (subject,'S1','Loc4','WhiskStim','A'),
            (subject,'S1','Loc5','WhiskStim','A'),
            (subject,'S1','Loc5','WhiskStim','C'),
            (subject,'VPLM','Loc6','WhiskStim','A'),
            (subject,'VPLM','Loc6','WhiskStim','C')]
channel_sequence = np.array([9,8,10,7,13,4,12,5,15,2,16,1,14,3,11,6])
for session in sessions:
    load_and_pack_timestamps(base_loc,session)

# %% [markdown]
# # play with the kwik files

# %%
# %matplotlib inline
from spike2_utils import plot_all_units

loc = r'C:\Users\bsriram\Desktop\Data\PGRN\Sessions\PGRN_WT_3_Loc2_VisStim_B'
out = plot_all_units(loc)

# %% [markdown]
# # Write qsub file for analysis

# %%
from spike2_utils import write_qsub_file
import os
base = r'C:\Users\bsriram\Desktop\Data\PGRN\Sessions'

for fold in os.listdir(base):
    write_qsub_file(base ,fold)

# %% [markdown]
# # Write the params file

# %%
from spike2_utils import write_params_file
import os
base = r'C:\Users\bsriram\Desktop\Data\PGRN\Sessions'

for fold in os.listdir(base):
    write_params_file(base ,fold)

# %% [markdown]
# # check the number of events in the folder

# %%
import os
import numpy as np

base = r'C:\Users\bsriram\Desktop\Data\PGRN\Sessions'

for fold in os.listdir(base):
    ts = np.fromfile(os.path.join(base,fold,'timestamps.np'))
    print('{0} : {1}'.format(fold,ts.size))

# %% [markdown]
# # plot mua by channel

# %%
# %matplotlib inline
from spike2_utils import analyze_mua_by_channel
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.pyplot as plt

locs = [r'C:\Users\bsriram\Desktop\Data\PGRN\Sessions\PGRN_HOM_1_Loc1_VisStim_D',
        r'C:\Users\bsriram\Desktop\Data\PGRN\Sessions\PGRN_HOM_2_Loc1_VisStim_D',
        r'C:\Users\bsriram\Desktop\Data\PGRN\Sessions\PGRN_HOM_3_Loc1_VisStim_D',
        r'C:\Users\bsriram\Desktop\Data\PGRN\Sessions\PGRN_HOM_4_Loc1_VisStim_D',
        r'C:\Users\bsriram\Desktop\Data\PGRN\Sessions\PGRN_HOM_5_Loc1_VisStim_D',]
with PdfPages('trial.pdf') as pdf:
    for loc in locs:
        f = analyze_mua_by_channel(loc,show_plot=False)
        pdf.savefig(f)
        plt.close()
